# %%
import nltk
nltk.download("stopwords")
nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Kritika
# [nltk_data]     Panta\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Kritika
# [nltk_data]     Panta\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Kritika
# [nltk_data]     Panta\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Kritika
# [nltk_data]     Panta\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import os, re, string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

STOPWORDS = set(stopwords.words('english'))
LEMMATIZER = WordNetLemmatizer()

# %%
# Load text files 
def load_text_files(folder_path):
    data = {}
    doc_id_to_filename = {}
    doc_id = 0
    print(f"Scanning folder: {folder_path}")
    for filename in os.listdir(folder_path):
        if filename.lower() == "queries.txt":
            continue
        if filename.endswith(".txt"):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, "r", encoding="utf-8") as f:
                content = f.read()
                data[doc_id] = content
                doc_id_to_filename[doc_id] = filename
                print(f"Loaded doc_id {doc_id} -> {filename}")
                doc_id += 1

    print(f"Total documents loaded: {len(data)}")
    return data, doc_id_to_filename

# %%
# Text cleaning
def clean_text(text):
    text = text.lower()
    text = re.sub(r"[^a-zA-Z\s]", "", text)
    tokens = word_tokenize(text)

    cleaned_tokens = [
        LEMMATIZER.lemmatize(word)
        for word in tokens
        if word not in STOPWORDS and len(word) > 1
    ]
    return " ".join(cleaned_tokens)

# %%
# Generate queries file
def generate_queries_file(output_file):

    queries = [
        "social crimes in Nepal",
        "wildlife attacks on highways",
        "rise in suicide cases",
        "elephant attacks and highway safety",
        "drug abuse and narcotics cases",
        "Apple M5 AI performance",
        "police awareness programs",
        "increase in criminal cases in Kathmandu",
        "ray tracing and graphics in M5",
        "rise in bank fraud incidents",
        "attempt to murder cases Nepal",
        "rape and sexual violence statistics",
        "polygamy crime cases in Nepal",
        "human wildlife conflict in Nepal",
        "forensic investigation Nepal",
        "road accident deaths in Nepal"
    ]

    with open(output_file, "w", encoding="utf-8") as f:
        for q in queries:
            f.write(q + "\n")

    print(f"\nGenerated queries.txt at: {output_file}")
    return queries

# %%
# Load Queries From File
def load_queries(query_file):
    queries = []
    print(f"\nLoading queries from: {query_file}")

    with open(query_file, "r", encoding="utf-8") as f:
        for line in f:
            q = line.strip()
            if q:
                queries.append(q)
                print(f"Loaded query: {q}")

    return queries

# %%
# Compute TF-IDF + Cosine Similarity
def compute_similarity(doc_texts, queries, doc_id_to_filename, output_file="similarity_results.txt"):
    print("\nComputing TF-IDF vectors...")

    vectorizer = TfidfVectorizer()

    doc_vectors = vectorizer.fit_transform(doc_texts)

    with open(output_file, "w", encoding="utf-8") as result_file:

        for query in queries:
            cleaned_query = clean_text(query)
            query_vector = vectorizer.transform([cleaned_query])
            scores = cosine_similarity(query_vector, doc_vectors)[0]
            ranking = sorted(
                list(enumerate(scores)),
                key=lambda x: x[1],
                reverse=True
            )
            print(f"\nQuery: {query}")
            result_file.write(f"\nQuery: {query}\n")
            result_file.write("="*60 + "\n")

            for rank, (doc_id, score) in enumerate(ranking, start=1):
                filename = doc_id_to_filename[doc_id]
                output_line = f"Rank {rank}: {filename}  |  Similarity = {score:.4f}"
                print(output_line)
                result_file.write(output_line + "\n")

            result_file.write("\n")

    print(f"\nSimilarity results saved to: {output_file}")

# %%
# Main Program
def main():

    folder_path = r"C:\Users\Kritika Panta\Desktop\Week three assignment"
    query_file = os.path.join(folder_path, "queries.txt")

    generate_queries_file(query_file)

    data, doc_id_to_filename = load_text_files(folder_path)

    cleaned_docs = []
    for doc_id, content in data.items():
        cleaned = clean_text(content)
        cleaned_docs.append(cleaned)
        print(f"Cleaned Doc {doc_id}: {cleaned[:80]}...")

    queries = load_queries(query_file)

    compute_similarity(cleaned_docs, queries, doc_id_to_filename)

if __name__ == "__main__":
    main()
# Out:
# Generated queries.txt at: C:\Users\Kritika Panta\Desktop\Week three assignment\queries.txt
# Scanning folder: C:\Users\Kritika Panta\Desktop\Week three assignment
# Loaded doc_id 0 -> 336 Cases of Violence against Women and Girls Committed During Lockdown.txt
# Loaded doc_id 1 -> Apple unleashes M5, the next big leap in AI performance for Apple silicon.txt
# Loaded doc_id 2 -> Incidents of social crime rise to 162 a day in Nepal.txt
# Loaded doc_id 3 -> Social crimes are rising across the country, says police.txt
# Loaded doc_id 4 -> Social crimes on the rise, but hard to intercept, police say.txt
# Loaded doc_id 5 -> Wildlife risks grow along forested Rautahat highways.txt
# Total documents loaded: 6
# Cleaned Doc 0: case violence woman girl committed lockdown may may kathmandu lockdown worec doc...
# Cleaned Doc 1: october apple unleashes next big leap ai performance apple silicon delivers peak...
# Cleaned Doc 2: incident social crime rise day nepal rising nepal thu december staff reporterkat...
# Cleaned Doc 3: social crime rising across country say police total criminal case recorded acros...
# Cleaned Doc 4: social crime rise hard intercept police say social crime increasing kathmandu va...
# Cleaned Doc 5: wildlife risk grow along forested rautahat highway frequent encounter elephant a...
#
# Loading queries from: C:\Users\Kritika Panta\Desktop\Week three assignment\queries.txt
# Loaded query: social crimes in Nepal
# Loaded query: wildlife attacks on highways
# Loaded query: rise in suicide cases
# Loaded query: elephant attacks and highway safety
# Loaded query: drug abuse and narcotics cases
# Loaded query: Apple M5 AI performance
# Loaded query: police awareness programs
# Loaded query: increase in criminal cases in Kathmandu
# Loaded query: ray tracing and graphics in M5
# Loaded query: rise in bank fraud incidents
# Loaded query: attempt to murder cases Nepal
# Loaded query: rape and sexual violence statistics
# Loaded query: polygamy crime cases in Nepal
# Loaded query: human wildlife conflict in Nepal
# Loaded query: forensic investigation Nepal
# Loaded query: road accident deaths in Nepal
#
# Computing TF-IDF vectors...
#
# Query: social crimes in Nepal
# Rank 1: Social crimes on the rise, but hard to intercept, police say.txt  |  Similarity = 0.4799
# Rank 2: Social crimes are rising across the country, says police.txt  |  Similarity = 0.2917
# Rank 3: Incidents of social crime rise to 162 a day in Nepal.txt  |  Similarity = 0.2831
# Rank 4: 336 Cases of Violence against Women and Girls Committed During Lockdown.txt  |  Similarity = 0.0434
# Rank 5: Apple unleashes M5, the next big leap in AI performance for Apple silicon.txt  |  Similarity = 0.0000
# Rank 6: Wildlife risks grow along forested Rautahat highways.txt  |  Similarity = 0.0000
#
# Query: wildlife attacks on highways
# Rank 1: Wildlife risks grow along forested Rautahat highways.txt  |  Similarity = 0.3296
# Rank 2: Social crimes on the rise, but hard to intercept, police say.txt  |  Similarity = 0.0177
# Rank 3: 336 Cases of Violence against Women and Girls Committed During Lockdown.txt  |  Similarity = 0.0000
# Rank 4: Apple unleashes M5, the next big leap in AI performance for Apple silicon.txt  |  Similarity = 0.0000
# Rank 5: Incidents of social crime rise to 162 a day in Nepal.txt  |  Similarity = 0.0000
# Rank 6: Social crimes are rising across the country, says police.txt  |  Similarity = 0.0000
#
# Query: rise in suicide cases
# Rank 1: 336 Cases of Violence against Women and Girls Committed During Lockdown.txt  |  Similarity = 0.3592
# Rank 2: Social crimes are rising across the country, says police.txt  |  Similarity = 0.2846
# Rank 3: Incidents of social crime rise to 162 a day in Nepal.txt  |  Similarity = 0.2516
# Rank 4: Social crimes on the rise, but hard to intercept, police say.txt  |  Similarity = 0.1255
# Rank 5: Wildlife risks grow along forested Rautahat highways.txt  |  Similarity = 0.0089
# Rank 6: Apple unleashes M5, the next big leap in AI performance for Apple silicon.txt  |  Similarity = 0.0000
#
# Query: elephant attacks and highway safety
# Rank 1: Wildlife risks grow along forested Rautahat highways.txt  |  Similarity = 0.5385
# Rank 2: Social crimes on the rise, but hard to intercept, police say.txt  |  Similarity = 0.0151
# Rank 3: 336 Cases of Violence against Women and Girls Committed During Lockdown.txt  |  Similarity = 0.0000
# Rank 4: Apple unleashes M5, the next big leap in AI performance for Apple silicon.txt  |  Similarity = 0.0000
# Rank 5: Incidents of social crime rise to 162 a day in Nepal.txt  |  Similarity = 0.0000
# Rank 6: Social crimes are rising across the country, says police.txt  |  Similarity = 0.0000
#
# Query: drug abuse and narcotics cases
# Rank 1: 336 Cases of Violence against Women and Girls Committed During Lockdown.txt  |  Similarity = 0.2099
# Rank 2: Social crimes are rising across the country, says police.txt  |  Similarity = 0.2057
# Rank 3: Incidents of social crime rise to 162 a day in Nepal.txt  |  Similarity = 0.1178
# Rank 4: Social crimes on the rise, but hard to intercept, police say.txt  |  Similarity = 0.0690
# Rank 5: Apple unleashes M5, the next big leap in AI performance for Apple silicon.txt  |  Similarity = 0.0000
# Rank 6: Wildlife risks grow along forested Rautahat highways.txt  |  Similarity = 0.0000
#
# Query: Apple M5 AI performance
# Rank 1: Apple unleashes M5, the next big leap in AI performance for Apple silicon.txt  |  Similarity = 0.5702
# Rank 2: 336 Cases of Violence against Women and Girls Committed During Lockdown.txt  |  Similarity = 0.0000
# Rank 3: Incidents of social crime rise to 162 a day in Nepal.txt  |  Similarity = 0.0000
# Rank 4: Social crimes are rising across the country, says police.txt  |  Similarity = 0.0000
# Rank 5: Social crimes on the rise, but hard to intercept, police say.txt  |  Similarity = 0.0000
# Rank 6: Wildlife risks grow along forested Rautahat highways.txt  |  Similarity = 0.0000
#
# Query: police awareness programs
# Rank 1: Social crimes are rising across the country, says police.txt  |  Similarity = 0.2194
# Rank 2: Incidents of social crime rise to 162 a day in Nepal.txt  |  Similarity = 0.2024
# Rank 3: Social crimes on the rise, but hard to intercept, police say.txt  |  Similarity = 0.1684
# Rank 4: Wildlife risks grow along forested Rautahat highways.txt  |  Similarity = 0.0250
# Rank 5: 336 Cases of Violence against Women and Girls Committed During Lockdown.txt  |  Similarity = 0.0102
# Rank 6: Apple unleashes M5, the next big leap in AI performance for Apple silicon.txt  |  Similarity = 0.0000
#
# Query: increase in criminal cases in Kathmandu
# Rank 1: Social crimes are rising across the country, says police.txt  |  Similarity = 0.3599
# Rank 2: 336 Cases of Violence against Women and Girls Committed During Lockdown.txt  |  Similarity = 0.2632
# Rank 3: Social crimes on the rise, but hard to intercept, police say.txt  |  Similarity = 0.2569
# Rank 4: Incidents of social crime rise to 162 a day in Nepal.txt  |  Similarity = 0.1620
# Rank 5: Apple unleashes M5, the next big leap in AI performance for Apple silicon.txt  |  Similarity = 0.0206
# Rank 6: Wildlife risks grow along forested Rautahat highways.txt  |  Similarity = 0.0000
#
# Query: ray tracing and graphics in M5
# Rank 1: Apple unleashes M5, the next big leap in AI performance for Apple silicon.txt  |  Similarity = 0.1104
# Rank 2: 336 Cases of Violence against Women and Girls Committed During Lockdown.txt  |  Similarity = 0.0000
# Rank 3: Incidents of social crime rise to 162 a day in Nepal.txt  |  Similarity = 0.0000
# Rank 4: Social crimes are rising across the country, says police.txt  |  Similarity = 0.0000
# Rank 5: Social crimes on the rise, but hard to intercept, police say.txt  |  Similarity = 0.0000
# Rank 6: Wildlife risks grow along forested Rautahat highways.txt  |  Similarity = 0.0000
#
# Query: rise in bank fraud incidents
# Rank 1: Incidents of social crime rise to 162 a day in Nepal.txt  |  Similarity = 0.0664
# Rank 2: Social crimes are rising across the country, says police.txt  |  Similarity = 0.0576
# Rank 3: Wildlife risks grow along forested Rautahat highways.txt  |  Similarity = 0.0291
# Rank 4: Social crimes on the rise, but hard to intercept, police say.txt  |  Similarity = 0.0270
# Rank 5: 336 Cases of Violence against Women and Girls Committed During Lockdown.txt  |  Similarity = 0.0096
# Rank 6: Apple unleashes M5, the next big leap in AI performance for Apple silicon.txt  |  Similarity = 0.0000
#
# Query: attempt to murder cases Nepal
# Rank 1: 336 Cases of Violence against Women and Girls Committed During Lockdown.txt  |  Similarity = 0.3421
# Rank 2: Social crimes are rising across the country, says police.txt  |  Similarity = 0.3305
# Rank 3: Incidents of social crime rise to 162 a day in Nepal.txt  |  Similarity = 0.1982
# Rank 4: Social crimes on the rise, but hard to intercept, police say.txt  |  Similarity = 0.0742
# Rank 5: Apple unleashes M5, the next big leap in AI performance for Apple silicon.txt  |  Similarity = 0.0000
# Rank 6: Wildlife risks grow along forested Rautahat highways.txt  |  Similarity = 0.0000
#
# Query: rape and sexual violence statistics
# Rank 1: 336 Cases of Violence against Women and Girls Committed During Lockdown.txt  |  Similarity = 0.2151
# Rank 2: Incidents of social crime rise to 162 a day in Nepal.txt  |  Similarity = 0.0585
# Rank 3: Social crimes are rising across the country, says police.txt  |  Similarity = 0.0212
# Rank 4: Apple unleashes M5, the next big leap in AI performance for Apple silicon.txt  |  Similarity = 0.0000
# Rank 5: Social crimes on the rise, but hard to intercept, police say.txt  |  Similarity = 0.0000
# Rank 6: Wildlife risks grow along forested Rautahat highways.txt  |  Similarity = 0.0000
#
# Query: polygamy crime cases in Nepal
# Rank 1: Social crimes are rising across the country, says police.txt  |  Similarity = 0.3800
# Rank 2: Incidents of social crime rise to 162 a day in Nepal.txt  |  Similarity = 0.2937
# Rank 3: Social crimes on the rise, but hard to intercept, police say.txt  |  Similarity = 0.2814
# Rank 4: 336 Cases of Violence against Women and Girls Committed During Lockdown.txt  |  Similarity = 0.2398
# Rank 5: Apple unleashes M5, the next big leap in AI performance for Apple silicon.txt  |  Similarity = 0.0000
# Rank 6: Wildlife risks grow along forested Rautahat highways.txt  |  Similarity = 0.0000
#
# Query: human wildlife conflict in Nepal
# Rank 1: Wildlife risks grow along forested Rautahat highways.txt  |  Similarity = 0.0999
# Rank 2: Social crimes are rising across the country, says police.txt  |  Similarity = 0.0500
# Rank 3: Incidents of social crime rise to 162 a day in Nepal.txt  |  Similarity = 0.0453
# Rank 4: 336 Cases of Violence against Women and Girls Committed During Lockdown.txt  |  Similarity = 0.0327
# Rank 5: Social crimes on the rise, but hard to intercept, police say.txt  |  Similarity = 0.0087
# Rank 6: Apple unleashes M5, the next big leap in AI performance for Apple silicon.txt  |  Similarity = 0.0000
#
# Query: forensic investigation Nepal
# Rank 1: Social crimes are rising across the country, says police.txt  |  Similarity = 0.1385
# Rank 2: Incidents of social crime rise to 162 a day in Nepal.txt  |  Similarity = 0.0554
# Rank 3: 336 Cases of Violence against Women and Girls Committed During Lockdown.txt  |  Similarity = 0.0242
# Rank 4: Social crimes on the rise, but hard to intercept, police say.txt  |  Similarity = 0.0107
# Rank 5: Apple unleashes M5, the next big leap in AI performance for Apple silicon.txt  |  Similarity = 0.0000
# Rank 6: Wildlife risks grow along forested Rautahat highways.txt  |  Similarity = 0.0000
#
# Query: road accident deaths in Nepal
# Rank 1: Social crimes are rising across the country, says police.txt  |  Similarity = 0.1118
# Rank 2: Incidents of social crime rise to 162 a day in Nepal.txt  |  Similarity = 0.0480
# Rank 3: Wildlife risks grow along forested Rautahat highways.txt  |  Similarity = 0.0336
# Rank 4: Social crimes on the rise, but hard to intercept, police say.txt  |  Similarity = 0.0092
# Rank 5: 336 Cases of Violence against Women and Girls Committed During Lockdown.txt  |  Similarity = 0.0072
# Rank 6: Apple unleashes M5, the next big leap in AI performance for Apple silicon.txt  |  Similarity = 0.0000
#
# Similarity results saved to: similarity_results.txt
